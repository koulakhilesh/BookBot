# %%
from suggestmodel import suggestModel
suggestModelClass=suggestModel(df_corpus_path='df_corpus.csv',df_bookauthor_path='df_bookauthor.csv',df_merge_path='df_merge.csv')

# %%
#text=input()
text= 'I just finished Great Expectations and I’m looking for a similar book. Any help is welcome.'

# %%
suggestModelClass.suggestmeabook(text)
# Out:
# A Great and Terrible King: Edward I and the Forging of Britain
# A Short History of Byzantium
# The Norman Conquest
# The Time Traveler's Guide to Medieval England: A Handbook for Visitors to the Fourteenth Century
# The Norman Kingdom of Sicily
