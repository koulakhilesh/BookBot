# %%
from scripts.suggestmodel import suggestModel
suggestModelClass=suggestModel(df_corpus_path='data/df_corpus.csv',df_bookauthor_path='data/df_bookauthor.csv',df_merge_path='data/df_merge.csv',notebook=True)
#df_clean=suggestModelClass.cleanText()
#suggestModelClass.trainData()

# %%
#text=input()
text= 'I just finished Great Expectations and I’m looking for a similar book. Any help is welcome.'

# %%
suggestModelClass.suggestmeabook(text)
# Out:
# The Norman Kingdom of Sicily
# A Short History of Byzantium
# Peter the Great: His Life and World
# The Norman Conquest
# Through the Eye of a Needle: Wealth, the Fall of Rome, and the Making of Christianity in the West, 350-550 AD
